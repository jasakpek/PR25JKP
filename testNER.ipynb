# %% [markdown]
# Ta dokument je namenjen testiranju in ucenju uporabe NER-a, saj se prvic srecujem z njim.

# %% [markdown]
# **uporaba CLASSLA**

# %% [markdown]
# V drugo sem imel vec srece, classla namrec podpira slovenski jezik tudi za NER.

# %%
import classla

# %%
classla.download("sl")
# Out:
# Downloading https://raw.githubusercontent.com/clarinsi/classla-resources/main/resources_2.2.json: 15.9kB [00:00, 17.1MB/s]
# 2025-06-01 22:10:21 INFO: Downloading these customized packages for language: sl (Slovenian)...
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | standard |
# | pos       | standard |
# | lemma     | standard |
# | depparse  | standard |
# | ner       | standard |
# | pretrain  | standard |
# ========================
#
# 2025-06-01 22:11:07 INFO: File exists: /data/home/jasa/classla_resources/sl/pos/standard.pt.
# 2025-06-01 22:11:08 INFO: File exists: /data/home/jasa/classla_resources/sl/lemma/standard.pt.
# 2025-06-01 22:11:09 INFO: File exists: /data/home/jasa/classla_resources/sl/depparse/standard.pt.
# 2025-06-01 22:11:10 INFO: File exists: /data/home/jasa/classla_resources/sl/ner/standard.pt.
# 2025-06-01 22:11:12 INFO: File exists: /data/home/jasa/classla_resources/sl/pretrain/standard.pt.
# 2025-06-01 22:11:12 INFO: Finished downloading models and saved to /data/home/jasa/classla_resources.

# %%
nlp = classla.Pipeline("sl", processors="tokenize,pos,lemma,ner", use_gpu=True)

doc = nlp("Predsednik vlade Robert Golob je obiskal Novo Gorico.")

for ent in doc.ents:
    print(ent.text, ent.type)
# Out:
# 2025-06-01 22:11:12 INFO: Loading these models for language: sl (Slovenian):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | standard |
# | pos       | standard |
# | lemma     | standard |
# | ner       | standard |
# ========================
#
# 2025-06-01 22:11:13 INFO: Use device: gpu
# 2025-06-01 22:11:13 INFO: Loading: tokenize
# 2025-06-01 22:11:13 INFO: Loading: pos
# 2025-06-01 22:11:56 INFO: Loading: lemma
# 2025-06-01 22:12:15 INFO: Loading: ner
# 2025-06-01 22:12:15 INFO: Done loading processors!
# Robert Golob PER
# Novo Gorico LOC

# %% [markdown]
# **Zgoraj se je classla dobro obnesla, a se je hitro zataknilo**

# %%
import os
import json

# %% [markdown]
# nastavimo podatke za direktori

# %%
input_folder = './json-test/'

# %% [markdown]
# nalozimo clanke v pomnilnik:

# %%
clanki = []
for filename in os.listdir(input_folder):
    if filename.endswith('.json'):
        file_path = os.path.join(input_folder, filename)
        with open(file_path, 'r', encoding='utf-8') as f:
            try:
                data = json.load(f)
                if isinstance(data, list):
                    clanki.extend(data)
                else:
                    clanki.append(data)
            except json.JSONDecodeError as e:
                print(f"Napaka pri branju {filename}: {e}")

# %% [markdown]
# hitra testna koda:

# %%
for i, clanek in enumerate(clanki, 1):
    naslov = clanek.get("title", f"Članek {i}")
    besedilo = clanek.get("text", "")

    doc = nlp(besedilo)

    imena = set()
    lokacije = set()

    for ent in doc.ents:
        if ent.type == "PER":
            imena.add(ent.text)
        elif ent.type == "LOC":
            lokacije.add(ent.text)

    print(f"\n=== {naslov} ===")
    if imena:
        print("Imena:")
        for ime in sorted(imena):
            print(f" - {ime}")
    else:
        print("Imena: (ni najdenih)")

    if lokacije:
        print("Lokacije:")
        for lok in sorted(lokacije):
            print(f" - {lok}")
    else:
        print("Lokacije: (ni najdenih)")
# Out:
# === Predsednik vlade Robert Golob je obiskal Novo Gorico. ===
# Imena:
#  - Robert Golob
# Lokacije:
#  - Novo Gorico
#
# === Prometno nesrečo, v kateri je umrlo 12 ljudi, povzročil tovornjak ===
# Imena:
#  -  je včeraj pretr
#  - eri je umrlo 12
#  - orjen tovornjak
# Lokacije:
#  - Bratislava
#  - Nesre
#  - Nitra
#  - Slovaška
#  - Slovaško
#  - e umr
#  - ometna ne
#
# === Še vedno ni jasno, kdo bo plačal 250 tisoč evrov za zdravljenje beguncev in migrantov ===
# Imena:
#  -  bl
#  -  da se zdr
#  -  vedno pou
#  - , a
#  - agajne, še
#  - ajo na Zav
#  - ali so ga
#  - eno
#  - ern
#  - ga vsako l
#  - k predstav
#  - n n
#  - o zaradi b
#  - r namenjen
#  - rše
#  - stveno zav
#  - trs
#  - una
#  - van
#  - vi
#  - zdr
# Lokacije:
#  - , ki ga v
#  - Slovenijo
#  - be, ki pr
#
# === 'Če zmaga, bo to dokaz, da imajo Slovaki dovolj korupcije' ===
# Imena:
#  -  v zadnji
#  -  zadnjih
#  - ,4 milijo
#  - Andrej Kiska
#  - Jana Kuciaka
#  - Marošem Šefčovičem
#  - Zuzana Čaputova
#  - anji p
#  - bri lj
#  - e storij
#  - glasna a
#  - glasna aktiv
#  - i ljudje
#  - i v drug
#  - ivcev,
#  - ka proti kor
#  - roti korupciji
#  - rošem Šefčov
#  - se
#  - trani, kj
#  - u predse
#  - ualni pr
#  - ugem krog
#  - zmago zl
#  - Čaputova
# Lokacije:
#  - "Za zmag
#  - Slovaško
#  - avila pr
#  - ji Fac
#  - namenijo s
#  - raziskav
#  - s. V nje
#
# === Bodo Slovaki prvič v zgodovini izvolili žensko predsednico? ===
# Imena:
#  - -letna liberaln
#  - Maroš Še
#  - Maroš Šefčovič
#  - Zuzano Čaputovo
#  - e Smer,
#  - ike možnosti
#  - iral s podpo
#  - je prejel 18,66
#  - radnih rezul
#  - zgodovini Sl
#  - Čaputova
# Lokacije:
#  - Slovaške
#  - datka, k
#  - drugem k
#  - otka gla
#
# === Prometno nesrečo, v kateri je umrlo 12 ljudi, povzročil tovornjak ===
# Imena:
#  -  je včeraj pretr
#  - eri je umrlo 12
#  - orjen tovornjak
# Lokacije:
#  - Bratislava
#  - Nesre
#  - Nitra
#  - Slovaška
#  - Slovaško
#  - e umr
#  - ometna ne

# %% [markdown]
# **Rezultat**
# razocaranje, imena zaznava katastrofalno, ker bi bilo mozno da se pojavljajo cudni znaki, bom probal seenkrat in sicer z ociscenim besedilom.

# %% [markdown]
# Koda za ciscenje besedila:

# %%
import re

def ocisti_besedilo(besedilo):
    besedilo = re.sub(r"\s+", " ", besedilo)  # Odvečne beline
    besedilo = re.sub(r"[^\w\s.,!?žščćčŠŽČĆ]", "", besedilo)  # Neobičajni znaki
    return besedilo.strip()

# %% [markdown]
# Ponovno pozenimo enako kodo kot zgoraj:

# %%
for i, clanek in enumerate(clanki, 1):
    naslov = clanek.get("title", f"Članek {i}")
    besedilo = clanek.get("text", "")

    doc = nlp(ocisti_besedilo(besedilo))

    imena = set()
    lokacije = set()

    for ent in doc.ents:
        if ent.type == "PER":
            imena.add(ent.text)
        elif ent.type == "LOC":
            lokacije.add(ent.text)

    print(f"\n=== {naslov} ===")
    if imena:
        print("Imena:")
        for ime in sorted(imena):
            print(f" - {ime}")
    else:
        print("Imena: (ni najdenih)")

    if lokacije:
        print("Lokacije:")
        for lok in sorted(lokacije):
            print(f" - {lok}")
    else:
        print("Lokacije: (ni najdenih)")
# Out:
# === Predsednik vlade Robert Golob je obiskal Novo Gorico. ===
# Imena:
#  - Robert Golob
# Lokacije:
#  - Novo Gorico
#
# === Prometno nesrečo, v kateri je umrlo 12 ljudi, povzročil tovornjak ===
# Imena:
#  - Peter Pellegrini
#  - Zuzana Čaputova
# Lokacije:
#  - Bratislava
#  - Cipru
#  - Košic
#  - Nitra
#  - Slovaška
#  - Slovaškem
#  - Slovaško
#
# === Še vedno ni jasno, kdo bo plačal 250 tisoč evrov za zdravljenje beguncev in migrantov ===
# Imena:
#  - Damjan Kos
#  - Kos
#  - Samo Fakin
# Lokacije:
#  - Sloveniji
#  - Slovenijo
#
# === 'Če zmaga, bo to dokaz, da imajo Slovaki dovolj korupcije' ===
# Imena:
#  - Andrej Kiska
#  - Dennik N.
#  - Jana Kuciaka
#  - Macron
#  - Macron Če Čaputova
#  - Marošem Šefčovičem
#  - Matus Kostolny
#  - Milan Nic
#  - Roberta Fica
#  - Slovakov
#  - Zuzana Čaputova
#  - Čaputova
#  - Čaputovo
# Lokacije:
#  - Evrope
#  - Madžarskem
#  - Poljskem
#  - Slovaško
#
# === Bodo Slovaki prvič v zgodovini izvolili žensko predsednico? ===
# Imena:
#  - Andrej Kiska
#  - Jana Kuciaka
#  - Maroš Šefčovič
#  - Roberta Fica
#  - Zuzana Čaputova
#  - Zuzano Čaputovo
#  - Čaputova
# Lokacije:
#  - Slovaška
#  - Slovaške
#  - Slovaško
#
# === Prometno nesrečo, v kateri je umrlo 12 ljudi, povzročil tovornjak ===
# Imena:
#  - Peter Pellegrini
#  - Zuzana Čaputova
# Lokacije:
#  - Bratislava
#  - Cipru
#  - Košic
#  - Nitra
#  - Slovaška
#  - Slovaškem
#  - Slovaško

# %% [markdown]
# **Rezultat** <br>
# Pozitivno presenecenje, dosti bolje, morda celo dovolj. <br> Naletel sem na nov problem, in sicer imena so podvojena recimo Zuzana Caputova in Zuzano Caputovo, zato sem kodi dodal ze lemma, kar naj bi jo standariziral

# %%
for i, clanek in enumerate(clanki, 1):
    naslov = clanek.get("title", f"Članek {i}")
    besedilo = clanek.get("text", "")

    doc = nlp(ocisti_besedilo(besedilo))

    imena = set()
    lokacije = set()

    for ent in doc.ents:
        if ent.type == "PER":
            # Zberi leme vseh tokenov v entiteti
            leme = []
            for sent in doc.sentences:
                for token in sent.tokens:
                    if token.start_char >= ent.start_char and token.end_char <= ent.end_char:
                        leme.append(token.words[0].lemma)
            imena.add(" ".join(leme))

        elif ent.type == "LOC":
            lokacije.add(ent.text)

    print(f"\n=== {naslov} ===")
    if imena:
        print("Imena:")
        for ime in sorted(imena):
            print(f" - {ime}")
    else:
        print("Imena: (ni najdenih)")

    if lokacije:
        print("Lokacije:")
        for lok in sorted(lokacije):
            print(f" - {lok}")
    else:
        print("Lokacije: (ni najdenih)")
# Out:
# === Predsednik vlade Robert Golob je obiskal Novo Gorico. ===
# Imena:
#  - Robert Golob
# Lokacije:
#  - Novo Gorico
#
# === Prometno nesrečo, v kateri je umrlo 12 ljudi, povzročil tovornjak ===
# Imena:
#  - Peter Pellegrini
#  - Zuzana Čaputov
# Lokacije:
#  - Bratislava
#  - Cipru
#  - Košic
#  - Nitra
#  - Slovaška
#  - Slovaškem
#  - Slovaško
#
# === Še vedno ni jasno, kdo bo plačal 250 tisoč evrov za zdravljenje beguncev in migrantov ===
# Imena:
#  - Damjan Kos
#  - Kos
#  - Samo Fakin
# Lokacije:
#  - Sloveniji
#  - Slovenijo
#
# === 'Če zmaga, bo to dokaz, da imajo Slovaki dovolj korupcije' ===
# Imena:
#  - Andrej Kiska
#  - Dennik n.
#  - Jan Kuciak
#  - Macron
#  - Macron če Čaputov
#  - Maroš Šefčovič
#  - Matus Kostolny
#  - Milan Nic
#  - Robert Fico
#  - Slovak
#  - Zuzana Čaputov
#  - Čaputov
# Lokacije:
#  - Evrope
#  - Madžarskem
#  - Poljskem
#  - Slovaško
#
# === Bodo Slovaki prvič v zgodovini izvolili žensko predsednico? ===
# Imena:
#  - Andrej Kiska
#  - Jan Kuciak
#  - Maroš Šefčovič
#  - Robert Fico
#  - Zuzana Čaputov
#  - Čaputov
# Lokacije:
#  - Slovaška
#  - Slovaške
#  - Slovaško
#
# === Prometno nesrečo, v kateri je umrlo 12 ljudi, povzročil tovornjak ===
# Imena:
#  - Peter Pellegrini
#  - Zuzana Čaputov
# Lokacije:
#  - Bratislava
#  - Cipru
#  - Košic
#  - Nitra
#  - Slovaška
#  - Slovaškem
#  - Slovaško

# %% [markdown]
# **Tole mi je ze kar vsec** <br> nadaljujem tako da bo dejansko zmodificiran osnovni .json <br> ponovno nalozim datoteko

# %%
from collections import Counter
import time

# %%
with open('combined_test.json', 'r', encoding='utf-8') as f:
    clanki = json.load(f)

# %% [markdown]
# Spodnji for loop je nadgrajena verzija zgornjega, nad nalozenimi clanki namrec pozene prepoznavo entitet tako za osebe, lokacije ter organizacije, dobljene rezultate doda jsonu o clanku, pri tem si shrani tudi stevilo ponovitev.

# %%
start = time.time()
for i, clanek in enumerate(clanki, 1):
    naslov = clanek.get("title", f"Članek {i}")
    besedilo = clanek.get("text", "")

    doc = nlp(ocisti_besedilo(besedilo))

    osebe = Counter()
    lokacije = Counter()
    organizacije = Counter()

    for ent in doc.ents:
        leme = []
        for sent in doc.sentences:
            for token in sent.tokens:
                if token.start_char >= ent.start_char and token.end_char <= ent.end_char:
                    leme.append(token.words[0].lemma)
        besedilo_entitete = " ".join(leme) if leme else ent.text

        if ent.type == "PER":
            osebe[besedilo_entitete] += 1
        elif ent.type == "LOC":
            lokacije[besedilo_entitete] += 1
        elif ent.type == "ORG":
            organizacije[besedilo_entitete] += 1

    # Shrani vse v članek
    clanek["persons"] = dict(osebe)
    clanek["locations"] = dict(lokacije)
    clanek["organizations"] = dict(organizacije)

stop = time.time()
print(f"Za obdelavo {len(clanki)} clankov smo porabili: {stop-start:.0f} sekund")
print(f"Predviden cas za kategorizacijo vseh clankov: {(stop-start)*306000/(len(clanki)):.0f} sekund oz. {(stop-start)*306000/(len(clanki))/60:.0f} minut")
# Out:
# Za obdelavo 55 clankov smo porabili: 46 sekund
# Predviden cas za kategorizacijo vseh clankov: 256981 sekund oz. 4283 minut

# %% [markdown]
# **Predolgo traja** <br>
# skratka, ker classla tece le ne procesorju imamo en micken problemcic, rece se mu cas, prej bom umru kukr se bo to koncalo <br><br>
# **Resitev**
# multithreding, glej dokument ClasslaMultithr.py

# %% [markdown]
# testiram kako deluje:

# %%
for i, clanek in enumerate(clanki, 1):
    naslov = clanek.get("title", "")
    persons = clanek.get("persons")
    locations = clanek.get("locations")
    organizations = clanek.get("organizations")
    print(f"{i}.: {naslov}")
    print(f"   Persons: {persons}")
    print(f"   Locations.: {locations}")
    print(f"   Organizations.: {organizations}")
# Out:
# 1.: Biden za vodjo prometnega resorja izbral Peta Buttigiega
#    Persons: {'Buttigieg': 4, 'Biden': 1, 'Rahm Emanuel': 2, 'Eric Garcetti': 2, 'Rhode Island Gina Raimondo': 2, 'Buttgieg': 1, 'Bidn': 1, 'Beau Bidn': 1, 'Joe Biden': 1, 'South Benda': 2}
#    Locations.: {'Chicago': 2, 'Los Angeles': 2, 'Dallas': 1}
#    Organizations.: {'združen narod': 2, 'South bend tribuna': 2}
# 2.: Kaj je koronavirus in kakšni so simptomi okužbe?
#    Persons: {}
#    Locations.: {'Kitajska': 3, 'protivirusen': 5}
#    Organizations.: {}
# 3.: Kim Džong Un znova provocira. Zaradi jedrske eksplozije Obama zagrozil z novimi sankcijami
#    Persons: {'Yonhap': 2, 'Šinzo Abe': 2, 'Barack Obama': 2, 'Obama': 9, 'park Geun Hye': 3, 'Shinzo Abe': 3, 'Cho Taeyong': 2, 'Francois Hollande': 1, 'Yukiya Amano': 2}
#    Locations.: {'južen Koreja': 6, 'severen Koreja': 34, 'Japonska': 7, 'Kitajska': 2, 'francijajaponski': 1, 'Pjongjang': 9, 'Peking': 5, 'Korej': 1, 'Rusija': 1, 'ZDA': 1, 'Kitajsko': 3, 'japonski morje': 1, 'Slovenija': 5, 'severen Korejesloveni': 1, 'korejski polotok': 1, 'Punggyeri': 2, 'jedrski': 2, 'Seul': 4, 'Tokio': 5, 'Šanghaj': 6, 'Hongkong': 6, 'Sydney': 7, 'Singapur': 7}
#    Organizations.: {'tiskoven agencija južen Koreja': 1, 'varnosten svet ZN': 5, 'ZN': 4, 'varnosten svet': 1, 'G20': 1, 'mednaroden agencija za jedrski energija': 2, 'IAEA': 4, 'varnosten svet ZN.': 2, 'Vs ZN.': 1, 'MZZ': 1, 'evropski centralen banka': 8}
# 4.: Za vojaka četrtina dijakov
#    Persons: {'Jože Majcenovič': 1, 'Marjan Malešič': 1, 'Malešič': 2}
#    Locations.: {'Slovenija': 3}
#    Organizations.: {'obrambosloven raziskovalen center pri fakulteta za družben veda': 1, 'ministrstvo za obramba': 1, 'SV': 4, 'FDV': 1, 'Sv': 1, 'EU': 2}
# 5.: FOTO in VIDEO: Kriminalisti še ugotavljajo vzrok požara, v katerem je umrl moški
#    Persons: {}
#    Locations.: {'gospodinjski ulica': 1, 'Ljubljana': 1}
#    Organizations.: {'gasilski brigada Ljubljana': 1, 'prostovoljen gasilski društvo zgornji Šiška': 1, 'po informacija policijski uprava PU Ljubljana': 1, 'policijski uprava PU Ljubljana': 1, '24ur.com': 1, 'univerziteten kliničen center UKC Ljubljana': 2, 'UKC Ljubljana': 2, 'PU Ljubljana': 3}
# 6.: VIDEO: Za las ušla smrti v temnem tunelu
#    Persons: {}
#    Locations.: {}
#    Organizations.: {}
# 7.: Uran je v bolnišnici
#    Persons: {'Alojz Uran': 1, 'Anton Stres': 2, 'Uran': 13, 'Vlado Bizant': 4, 'Stres': 5, 'Andrej Saje': 5}
#    Locations.: {'Vatikan': 4, 'Slovenija': 4, 'Rim': 4, 'Sava': 4, 'Uran': 5, 'Trst': 5}
#    Organizations.: {'nadškofija Ljubljana': 1, 'kongregacija za škof': 4, 'oznanilo župnija sv. Jakob': 4, 'slovenski škofovski konferenca': 5}
# 8.: Za pravičnejšo porazdelitev zdravnikov
#    Persons: {}
#    Locations.: {'Posavje': 2, 'Brežice': 12, 'Krško': 8, 'Slovenija': 4}
#    Organizations.: {'direktor brežiški zdravstven dom': 1, 'zdravniški zbornica Slovenija': 2, 'ministrstvo za zdravje': 2, 'združenje zdravstven zavod Slovenija': 2}
# 9.: Zgolj petina Slovencev meni, da so moški in ženske obravnavani enako
#    Persons: {'Slovenka': 4, 'Slovenec': 4, 'Frans Timmermans': 4, 'Vera Jourov': 4, 'Ministrica': 1}
#    Locations.: {'Slovenija': 12, 'Islandija': 1, 'Švedska': 1, 'nov Zelandija': 1, 'združen država Amerika': 2, 'velik Britanija': 2, 'Norveška': 2, 'Luksemburg': 2, 'Danska': 2, 'Poljska': 2, 'Finska': 2, 'Belgija': 2, 'Mehika': 1, 'Irsko': 1, 'Avstralija': 1, 'Italija': 1, 'Libanon': 1, 'Vietnam': 1, 'Tajsko': 1, 'Indonezija': 1, 'Evropa': 5}
#    Organizations.: {'PricewaterhouseCoopers': 1, 'OECD': 1, 'Bloomberg': 2, 'Win International': 4, 'Mediana': 4, 'pred mednaroden': 3, 'evropski komisija': 8, 'EU': 22, 'STA': 4, 'evropski unija': 4}
# 10.: Zagorelo v bloku v Mežici: evakuirali 40 stanovalcev
#    Persons: {'Božidar Pezdevšek': 1, 'Pezdevšek': 1}
#    Locations.: {'Prežihov ulica': 1, 'Mežica': 1, 'Črna na Koroško': 1, 'Prevalje': 1, 'reševalec': 1}
#    Organizations.: {'RS za zaščita in reševanje poročati': 1, 'PGD Mežica': 1, 'zdravstven reševalen center koroški enota Ravne na Koroško': 2, 'policijski uprava Celje': 1}
# 11.: Za preskok čakalne vrste posredniku 20.000 evrov, med osumljenci tudi policisti
#    Persons: {'Uroš Smiljić': 8, 'Smiljič': 8, 'Simon Vrhunec': 10, 'Borut Miklavčič': 10, 'vrhunec': 10, 'Smiljić': 28, 'Robert Sušanj': 4, 'Sušanj': 22, 'Sušnja': 6, 'Vladimir Putin': 6, 'Sušanj Smiljič': 7, 'Sušnj': 7, 'Drago Menegalija': 3, 'Breceljkirurg': 8, 'Erik Brecelj': 9, 'Brecelj': 3}
#    Locations.: {'vožnja': 2, 'Ljubljana': 6}
#    Organizations.: {'univerziteten kliničen center UKC Ljubljana': 1, 'onkološki inštitut Ljubljana': 4, 'policijski uprava Ljubljana': 2, 'UKC': 24, '24ur': 29, 'novinar oddaja 24UR': 1, 'uprava za policijski specialnost': 4, 'javnost': 5, 'specializiran državen tožilstvo': 2, 'poseben oddelek SDT RS': 3, 'policija': 3, 'UKC korupcija': 2, 'UKC Ljubljana': 14, 'komisija za preprečevanje korupcija': 7, 'delo': 1, 'radio Slovenija': 2}
# 12.: Umrl je Alf Ramsey
#    Persons: {'Alf Ramsey': 1}
#    Locations.: {'Anglija': 1}
#    Organizations.: {}
# 13.: Pentagon: Iz Beograda ni konkretnih znakov o dejanskem sprejetju načel G-8
#    Persons: {}
#    Locations.: {'Kosovo': 1}
#    Organizations.: {}
# 14.: Zaradi burje na Hrvaškem možne zapore prometa
#    Persons: {}
#    Locations.: {'Jesenice vzhod': 1, 'Karavanke': 3, 'Avstrija': 1, 'prometnoinformacijski center': 1, 'Draženc': 2, 'Gruškovje': 2, 'Dobovec': 2, 'Zavrč': 2, 'Ljubljana': 2, 'Obala': 2, 'koperšmarjedragonje': 2, 'koperizolaportorož': 2, 'Dragonja': 2, 'Sečovlje': 2, 'Sočergo': 2, 'Kozinapodgrad': 2, 'Starod': 2, 'postojnailirski Bistrica': 2, 'Jelšane': 2, 'voznik': 2, 'burja': 2, 'Hrvaško': 1, 'na prometnoinformacijski center': 1, 'Hrvaško burja': 1, 'Hrvaško hrvaški': 1, 'ZagrebSplit': 1, 'svet rokmaslenički most': 1, 'Bosiljevorek': 1, 'Delnicekikovica': 1, 'jadranski magistrala': 1, 'Maslenicazaton Obrovaček': 1, 'Krk': 1, 'Pag': 1, 'aktualen': 1}
#    Organizations.: {}
# 15.: Predstavitev predloga proračuna v DZ
#    Persons: {}
#    Locations.: {}
#    Organizations.: {}
# 16.: Bruselj razočaral kandidatke
#    Persons: {'Jaroslaw Kalinowski': 2, 'Günter Verheugen': 1, 'Verheugen': 2}
#    Locations.: {'poljski': 1, 'Slovaško': 3, 'Litva': 3, 'širitev': 3, 'Bruselj': 1}
#    Organizations.: {'evropski unija': 6, 'EU': 22, 'evropski komisija': 7, 'evropski komisar': 1}
# 17.: Letala zadela dve kemični tovarni v predmestju Beograda
#    Persons: {}
#    Locations.: {'Beograd': 3, 'Zemun': 2, 'Surčin': 2, 'Košutnjak': 2}
#    Organizations.: {'Afp': 1, 'Itartass': 2}
# 18.: Neurje povzročilo veliko škode
#    Persons: {}
#    Locations.: {'Fale': 1, 'mežiški dolina': 3, 'Slovenj Gradec': 4, 'Šentanel': 1, 'Poljana Šentanel': 1, 'črn Sleme': 1, 'Mežica Črna': 1, 'Koroško': 1, 'Prevalje Prisoje': 1, 'Mežica': 1, 'Suhodolnica': 1, 'Brda': 1, 'mislinjski Dobrava': 1, 'Šmiklavž': 1, 'Golavabuka': 1, 'Dravograd Maribor': 2, 'Radlje': 2, 'Drava': 2, 'Pohorje': 2, 'dolenjskemzadnji': 3, 'nov mesto': 5, 'miren Peč': 4, 'Šentjernej': 5, 'Škocjan': 6, 'Otočec': 4, 'dolenji vas': 1, 'Sela': 1, 'Ratež': 3, 'na Otočec': 1, 'Lešnica': 2, 'bel cerkev': 1, 'Sela pri Ratež': 1, 'uršen sela': 2, 'Dobindol': 2, 'naliv': 4, 'štajerskemen': 4, 'Ruše': 11, 'Lovrenc': 5, 'Račfram': 5, 'Selnica': 5, 'Rušelovrenc': 5, 'falski pečina': 11, 'Mariborselnica': 5, 'Slemen': 5, 'močen naliv': 6, 'Maribordravograd': 6, 'toča': 8, 'Ljubljana': 9, 'neurje': 1, 'zaradi neurje': 1, 'Grmada': 1, 'Rudnik': 1, 'goriški Brd': 2}
#    Organizations.: {'policijski uprava PU Slovenj Gradec': 2, 'Prevent': 1, 'Spar': 1, 'občina Ribnica': 2, 'elektr': 1}
# 19.: 25 milijard za Afriko
#    Persons: {'Tony Blair': 1, 'Blair': 5, 'Džuničiro Koizumi': 1, 'Kofi Anan': 1, 'Olusegun Obasanjo': 2}
#    Locations.: {'Rusija': 4, 'Gleneagles': 3, 'Afrika': 8, 'Japonska': 3, 'velik Britanija': 3, 'ZDA': 3, 'Nemčija': 1, 'Francija': 1, 'Italija': 1, 'Kanada': 1, 'Alžirija': 1, 'Etiopija': 1, 'Gana': 1, 'Nigerija': 1, 'Senegal': 1, 'južnoafriški republika': 1, 'Tanzanija': 1, 'Kitajska': 2, 'Indija': 2, 'britanski': 1, 'London': 1}
#    Organizations.: {'G8': 4, 'varnosten svet ZN.': 1, 'afriški unija': 1, 'mednaroden denaren sklad': 1, 'IMF': 1, 'svetoven banka': 1, 'združen narod': 1, 'Gleneagles': 1}
# 20.: SVIZ in vlada dosegla dogovor
#    Persons: {'Igor Umek': 1, 'Branimir Štrukelj': 1, 'Umek': 3, 'Štrukelj': 2, 'Borut Pahor': 1, 'Štukelj': 2}
#    Locations.: {}
#    Organizations.: {'sindikat vzgoja , izobraževanje in znanost Slovenija Sviz': 1, 'Sviz': 2}
# 21.: Pri omejevanju cen energentov za 'skupni evropski pristop'
#    Persons: {'Petr Fiala': 1, 'Charles Michel': 1, 'Fiala': 4, 'Michel': 5, 'Ursula von der Leyen': 4, 'Josep Borrell': 6, 'Borrell': 14, 'Robert Metsol': 1, 'Vladimir Putin': 1, 'Metsola': 1, 'Robert Golob': 4}
#    Locations.: {'Praga': 2, 'Bruselj': 3, 'Evropa': 4, 'Slovenija': 6, 'baltski morje': 4, 'Ukrajina': 24, 'Rusija': 12, 'praški grad': 3}
#    Organizations.: {'EU': 31, 'evropski svet': 1, 'evropski svet Michel': 2, 'evropski komisija': 3, 'predsednica komisija': 3, 'komisija': 5, 'STA': 6, 'Repowereu': 3, 'unija': 10, 'unija Ukrajina': 7, 'evropski parlament': 1, 'nujnost enotnost unija': 1, 'evropski političen skupnost': 1}
# 22.: V Murglah našli trupli
#    Persons: {}
#    Locations.: {'Murgle': 1}
#    Organizations.: {}
# 23.: Trump Britancem svetuje, naj EU ne plačajo za brexit
#    Persons: {'Donald Trump': 1, 'Britanec': 3, 'Theresa May': 1, 'Farage': 3, 'Nigel': 2, 'kritičen': 2, 'Mayeveznov': 3, 'Boris Johnson': 4, 'Trump': 5, 'Melania': 1, 'Elizabeta II.': 1, 'Johnson': 1}
#    Locations.: {'velik Britanija': 3, 'združen kraljestvo': 2, 'Bruselj London': 1, 'Britanec': 3, 'Bruselj': 4, 'ZDA': 1, 'Otok': 1, 'buckinghamski palača': 1, 'London': 2}
#    Organizations.: {'Sunday Times': 1, 'evropski unija': 1, 'evropski unijidejati': 2, 'unija': 6, 'EU': 1, 'Mayeva': 4, 'Sun': 4}
# 24.: Papež nagovoril bolne
#    Persons: {'Janez Pavel II.': 1, 'Jacques Chirac': 1, 'Bernardki Soubirous': 1, 'Francois Etchegaray': 1}
#    Locations.: {'Massabielle': 1, 'Lurd': 2, 'Tarbes': 2}
#    Organizations.: {}
# 25.: Burno soočenje: Nemec o pritiskih, Hojs o (različnih) vrednotah
#    Persons: {'Hojs': 43, 'Nemec': 36, 'Jaša Jenull': 10, 'Jenull': 28, 'Primc': 3, 'Janez Janša': 4, 'Boris a. Novak': 4, 'Fajon': 5, 'Šarec': 5, 'Mesec': 6, 'Nemec Hojs': 4, 'Šarc': 1, 'Fajonov': 1}
#    Locations.: {'Neonacista': 4, 'trg republika': 14, 'Prešernov trg': 8, 'republika Slovenija': 7, 'Poljska': 2, 'Madžarska': 2, 'Slovenija': 4}
#    Organizations.: {'iti': 2, 'SDS': 25, 'sova': 6, 'Prešernov trg': 7, 'policijski uprava Ljubljana': 2, 'PU Ljubljana': 3}
# 26.: 'Proti Lebanu ni nobenih resnih očitkov'
#    Persons: {'Andrej Krašek': 1, 'Rudolf Leban': 1, 'Krašek': 7, 'Leban Finec': 5, 'Leban': 10}
#    Locations.: {'Helsinki': 3, 'Slovenija': 4, 'Finska': 2}
#    Organizations.: {'Patria': 9, 'radio Slovenija': 3}
# 27.: Kako je v NLB pritekal denar iz Irana, ki je bil pod embargom?
#    Persons: {}
#    Locations.: {}
#    Organizations.: {}
# 28.: Primakov: ''Rusija bo izpolnila pogoje IMF''
#    Persons: {}
#    Locations.: {}
#    Organizations.: {}
# 29.: Preiskovalci niso potrdili sumov nasilja nad ukrajinskimi sirotami pri Postojni
#    Persons: {'Cvetka Kernel': 3, 'Slavina': 1, 'Kernelov': 1, 'koordinatorka': 1}
#    Locations.: {'Postojna': 1, 'Slavina': 4, 'Koper': 2, 'Severodoneck': 1}
#    Organizations.: {'ministrstvo za delo': 1, 'koordinatorka projekt': 2}
# 30.: Za velenjski referendum o azilnem domu ni pravne podlage
#    Persons: {'Bojan Kontič': 1, 'Mihael Letonje': 1, 'Iztok Mori': 1, 'Boštjan Šefic': 3}
#    Locations.: {'Velenje': 4, 'star vas': 3}
#    Organizations.: {'pobuda za vložitev zahteva': 1, 'civilen iniciativa': 1, 'SLS': 1, 'mesten občina Velenje': 1, 'v civilen iniciativen ogorčen civilen iniciativa': 1, 'omenjen objekt': 3}
# 31.: Zaključek konference o terorizmu
#    Persons: {'Nato George Robertson': 1, 'Robertson': 1, 'Amr Musa': 2, 'Al Kaida': 2, 'Dimitrij Rupel': 1, 'Rupel': 9, 'Benite Ferrerowaldner': 3, 'Solomon Passy': 3, 'Goran Svilanović': 3, 'tudi Ferrerowaldnerjev': 3, 'Ferrerowaldnerjev': 1, 'Svilanović': 1, 'Passy': 2}
#    Locations.: {'jugovzhoden Evropa': 1, 'Evropa': 1, 'Slovenija': 5, 'JV Evropa': 15, 'Balkan': 4, 'Bolgarija': 4, 'Romunija': 4, 'Jugoslavija': 1}
#    Organizations.: {'severnoatlantski zavezništvo': 1, 'generalen sekretar arabski liga': 1, 'arabski liga': 1, 'EU': 8, 'Nato': 8}
# 32.: Kafelnikov v finalu, Hingisova prvič poražena
#    Persons: {'Kafelnikov': 2, 'Norman': 1, 'Nemec': 1, 'Nicolas Kiefer': 1}
#    Locations.: {}
#    Organizations.: {}
# 33.: Depresivni Slovenci
#    Persons: {'Vesna Švab': 1, 'Švabov': 2, 'Slovenec': 5, 'Dorian Marušič': 3, 'Silva Pečar': 1}
#    Locations.: {'Slovenija': 2}
#    Organizations.: {'ministrstvo za zdravje': 3, 'inštitut za varovanje zdravje': 1, 'svetoven zdravstven organizacija': 1}
# 34.: Odkrili največji rudnik diamantov z zalogami za 3000 let
#    Persons: {'Rus': 1, 'Poligaj Astrobleme': 1, 'Nikolaj Philenko': 2}
#    Locations.: {'Rusija': 4, 'krater': 1, 'Sibirija': 1, 'diamant': 1, 'Poligaj': 3}
#    Organizations.: {'inštitut za geologija': 2}
# 35.: Lovcu, ki ga je napadel medved, izplačali preveč denarja
#    Persons: {}
#    Locations.: {}
#    Organizations.: {}
# 36.: Posnetki zahtevne reševalne akcije iz zalite Križne jame
#    Persons: {}
#    Locations.: {'Ljubljana': 2}
#    Organizations.: {'jamarski': 1, 'Jrs Postojna': 2, 'Jrs': 4, 'URSZR enota za hiter intervencija EHI': 2, 'ETP': 2, 'CZ občina Cerknica': 2, 'CZ Cerknica': 2, 'PGD Cerknica': 2, 'PDG Iga vas': 2, 'jezerski ščuka': 2, 'jamarski zveza': 2}
# 37.: Ko se za lepotne operacije ne odločimo zaradi želje po popolnosti
#    Persons: {}
#    Locations.: {}
#    Organizations.: {}
# 38.: Dopinška afera v Italiji
#    Persons: {}
#    Locations.: {}
#    Organizations.: {}
# 39.: Resnica o Jelinčičevem zaporu
#    Persons: {'Zmago Jelinčič': 1, 'Franci Kek': 3, 'Vitomir Rožej': 4, 'Jelinčič': 15, 'Rok Čeferin': 4, 'Kek': 4, 'Rožej': 4, 'Kek Jelinčič': 1, 'Darko Brlek': 2}
#    Locations.: {'Slovenija': 3, 'ljubljanski': 2}
#    Organizations.: {'aktiven Slovenija As': 1, 'SNS': 4, 'as': 3, 'delo': 4, 'slovenski novica': 2, 'Križanka': 2, 'moden Jani': 3, 'tv Slovenija': 3}
# 40.: Ljubljanska borza: veselje se nadaljuje
#    Persons: {}
#    Locations.: {}
#    Organizations.: {'Krka': 3, 'Lek': 2, 'Intereuropa': 1, 'banka Austria': 1, 'a': 1, 'Istrabenz': 1, 'slovenski odškodninski družba': 2, 'zvon 2': 2, 'zlat moneta 1': 2, 'kmečki družba holding': 8, 'KD Group': 4}
# 41.: Varčevali bodo le pri dežurstvih
#    Persons: {'Igor Antauer': 3, 'Simon Vrhunec': 1, 'Samo Fakin': 2, 'Fakin': 4}
#    Locations.: {}
#    Organizations.: {'zavod za zdravstven zavarovanje Slovenija ZZZS': 1, 'predlog': 1, 'ZZZS': 4, 'delodajalec': 2, 'skupščina ZZZS': 3, 'UKC': 1, 'UKC Ljubljana': 1, 'direktor ZZZS': 1}
# 42.: V Keniji popustil jez, umrlo več kot 40 ljudi, od tega 20 otrok
#    Persons: {}
#    Locations.: {'Solai': 1, 'Nairobi': 1, 'Nakur': 2, 'katastrofa': 2, 'rdeč križ': 10}
#    Organizations.: {'Patel': 1, 'Daily Nation': 2, 'BBC': 3}
# 43.: V spomin ženskemu pogumu
#    Persons: {'Dragica Čadež': 1}
#    Locations.: {'Ljubljana': 1, 'Metelkov': 1}
#    Organizations.: {}
# 44.: 'Zavlačevanje vlade pri izpolnjevanju obveznosti do STA nedopustno'
#    Persons: {'Margrethe Vestager': 1, 'Vera Jourov': 1, 'Vestagerjev': 11, 'Jourov': 11, 'Ursula von der Leyen': 1, 'Janez Lenarčič': 1, 'Nataša Goršek Mencin': 1, 'Bojan Veselinovič': 1, 'Veselinovič': 2, 'Igor Zorčič': 3, 'Lilija Kozlovič': 4, 'Zdravko Počivalšek': 4, 'Počivalšek': 5, 'Boštjan Koritnik': 5, 'Janja Sluga': 5}
#    Locations.: {'Slovenija': 7, 'Bruselj': 3}
#    Organizations.: {'STA': 27, 'služba generalen direktorat komisija za konkurenčnost': 2, 'evropski komisija': 10, 'EU': 7, 'komisija': 1, 'evropski listina': 4, 'evropski unija': 2, 'St': 7, 'urad vlada za komuniciranje Ukom': 3, 'DZ': 6, 'SMC': 21, 'ministrica za pravosodje': 3, 'Ukom': 5, 'ministrstvo za finance': 5}
# 45.: Kje bo Slovenija dobila denar za ukrepe in kakšna bo usoda EU?
#    Persons: {'Mojmir Mrak': 1, 'Mrak': 22, 'razrahljati': 5, 'Ursula von der Leyen': 5, 'Conte': 4, 'Merklov': 4}
#    Locations.: {'Slovenija': 9, 'Italija': 12, 'Nemčija': 21, 'Evropa': 20, 'Luksemburg': 5, 'Belgija': 5, 'Nizozemsko': 6}
#    Organizations.: {'evropski unija': 1, 'ECB': 12, 'evropski centralen banka': 2, 'evropski komisija': 2, 'evropski svet': 2, 'EU': 20, 'evropski solidarnosten mehanizem': 5, 'unija': 5}
# 46.: V Portorožu vam za ležanje na pomolu zaračunajo tri evre
#    Persons: {}
#    Locations.: {'Piran': 1}
#    Organizations.: {}
# 47.: Stopnja rodnosti v Sloveniji nad povprečjem EU
#    Persons: {'Slovenka': 5}
#    Locations.: {'Slovenija': 11, 'mlad mati': 2, 'Bolgarija': 4, 'romunijivajvečji': 3, 'Francija': 4, 'Malta': 4, 'Romunija': 1, 'Danska': 1, 'Italija': 3, 'star mati': 1, 'Španija': 2}
#    Organizations.: {'STA': 3, 'Eurostat': 2, 'evropski unija': 2, 'EU': 8, 'Surs': 2}
# 48.: Državni sekretar Petrič na japonskem zunanjem ministrstvu
#    Persons: {'Petrič': 1}
#    Locations.: {}
#    Organizations.: {'združen narod': 1, 'varnosten svet ZN': 1, 'ZN': 1, 'EU': 1, 'Nato': 1}
# 49.: S tem trikom sem odstranila žile in kapilare na nogah v samo 30 dneh
#    Persons: {'Mojca': 6, 'hvaljenje': 1}
#    Locations.: {'Ljubljana': 2, 'Slovenija': 2}
#    Organizations.: {'Emesto d. o. o.': 4}
# 50.: Arafat prispel v Moskvo
#    Persons: {'Arafat': 4, 'Igor Ivanov': 1, 'Jevgenij Primakov': 1, 'Boris Jelcin': 1, 'Palestinec': 2}
#    Locations.: {'Izrael': 2, 'Oslo': 2, 'palestinski': 2, 'Moskva': 3, 'Kitajska': 3, 'Japonska': 3, 'Indija': 3}
#    Organizations.: {}
# 51.: Sergejev: V enotah KFOR bo 3600 ruskih vojakov
#    Persons: {'William Cohen': 1, 'Igor Sergejev': 2, 'Sergejev': 2}
#    Locations.: {'Kosovo': 1, 'ZDA': 3, 'Francija': 1, 'Nemčija': 1, 'Helsinki': 2, 'Moskva': 2}
#    Organizations.: {'KFOR': 1, 'Kfor': 3}
# 52.: V Kočevju zagorelo v stanovanjskem bloku, evakuirali več kot 50 ljudi
#    Persons: {}
#    Locations.: {'turjaški naselje': 1, 'Kočevje': 1, 'poškodovan': 2}
#    Organizations.: {'RS za zaščita in reševanje': 2, 'PGD Kočevje': 2}
# 53.: Kriminalisti opravili hišno preiskavo na sedežu Abanke
#    Persons: {'Roman Glaser': 1, 'Glaser': 5, 'Romana Pajenk': 2, 'Matija Šešok': 2, 'Klemen Šešok': 2}
#    Locations.: {'Ljubljana': 5}
#    Organizations.: {'nacionalen preiskovalen urad': 1, 'generalen policijski uprava': 1, 'PU Maribor': 3, 'specializiran državen tožilstvo RS': 4, 'Abanka': 22, 'SiOL': 3, 'perutnina Ptuj': 14, 'Probanka': 2, 'Taxgroup': 2, 'NPU': 3, 'slovenski državen holding': 4, 'SDH': 4, 'nov KBM': 4, 'Apollo global management': 4}
# 54.: Reševanje tajskih dečkov zahtevalo prvo žrtev
#    Persons: {'Saman Gunan': 1, 'Rear Adm Arpakorn Yookongkaew': 2, 'Yookongkaew': 1}
#    Locations.: {}
#    Organizations.: {}
# 55.: Türk ne vidi razlogov za ukinitev vojske
#    Persons: {'Danilo Türk': 1, 'Türk': 3}
#    Locations.: {'Slovenija': 8, 'sever': 2, 'Srbija': 2}
#    Organizations.: {'slovenski vojska v Celje': 1, 'zveza policijski veteranski društvo Sever': 3}
